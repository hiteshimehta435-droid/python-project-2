# %%
print("Welcome to the Genrate Right-Angled Triangle Pattern and Analyze Number!")

print("Selece option: ")
print("1. Genrate Right Angled Triangle Pattern")
print("2. Analyze Number")
print("3. Exit")

choice = input("Enter your option: ")

if choice == "1":
    rows = int(input("Enter your choice of rows: "))

    if rows <= 0:
        print("Invalid row count!")
        

    print("Right-Angled Teiangle Pattern")
    for i in range(1, rows + 1):
        print("*" * i)

elif choice == "2":
    strat = int(input("Enter strating number: "))
    end = int(input("Enter ending number: "))

    print("Analyze Number")

    for num in range(strat, end + 1):

        if num == 5:
            pass

        if num % 2 == 0:
            print(num, "-Even")

        elif num % 3 == 0:
            print(num, "-Divisible by 3")

        else:
            print(num, "-other")

elif choice == "3":
    print("program Exited successfully.")
    print("Thank you")
    print("Heva good day!")
# Out:
# Welcome to the Genrate Right-Angled Triangle Pattern and Analyze Number!
# Selece option:
# 1. Genrate Right Angled Triangle Pattern
# 2. Analyze Number
# 3. Exit
# Enter your option:  1
# Enter your choice of rows:  7
# Right-Angled Teiangle Pattern
# *
# **
# ***
# ****
# *****
# ******
# *******
